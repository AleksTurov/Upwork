# %%
import os
import openai
import telebot
from pydub import AudioSegment
import speech_recognition as sr
from tempfile import NamedTemporaryFile

# Получение токенов из переменных окружения
TELEGRAM_BOT_TOKEN = os.getenv('TELEGRAM_BOT_TOKEN')
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')

# Инициализация бота и OpenAI
bot = telebot.TeleBot(TELEGRAM_BOT_TOKEN)
openai.api_key = OPENAI_API_KEY

# Инициализация распознавания речи
recognizer = sr.Recognizer()

# Словарь для хранения истории чата
chat_history = {}

def generate_openai_response(chat_id, text):
    """Генерация ответа с использованием модели GPT от OpenAI."""
    if chat_id not in chat_history:
        chat_history[chat_id] = [
            {"role": "system", "content": "You are Eva, a personal assistant."},
            {"role": "assistant", "content": "Hello! I'm Eva, your personal assistant."},
            {"role": "assistant", "content": 'Привет! Меня зовут Ева, я Ваш персональный консультант.'}
        ]

    chat_history[chat_id].append({"role": "user", "content": text})

    response = openai.ChatCompletion.create(
        model="gpt-4-0125-preview",  # Используйте актуальную модель
        messages=chat_history[chat_id],
        max_tokens=1000
    )

    if response.choices and response.choices[0].message.content:
        chat_history[chat_id].append({"role": "assistant", "content": response.choices[0].message.content})
        return response.choices[0].message.content
    else:
        return "Извините, я не смог понять ваше сообщение."

@bot.message_handler(func=lambda message: True)
def handle_messages(message):
    """Обработка текстовых и голосовых сообщений."""
    try:
        if message.content_type == 'text':
            text = message.text
        elif message.content_type == 'voice':
            file_info = bot.get_file(message.voice.file_id)
            downloaded_file = bot.download_file(file_info.file_path)

            with NamedTemporaryFile(suffix='.ogg') as ogg_file:
                ogg_file.write(downloaded_file)
                ogg_file.flush()
                audio = AudioSegment.from_ogg(ogg_file.name)
                
                with NamedTemporaryFile(suffix='.wav') as wav_file:
                    audio.export(wav_file.name, format='wav')
                    with sr.AudioFile(wav_file.name) as source:
                        audio_data = recognizer.record(source)
                        text = recognizer.recognize_google(audio_data, language='ru-RU')
        else:
            return  # Пропускаем обработку, если сообщение не текст и не голос

        response = generate_openai_response(message.chat.id, text)
        bot.reply_to(message, response)
    except Exception as e:
        print(f"Произошла ошибка: {e}")
        bot.reply_to(message, "Извините, произошла ошибка при обработке вашего сообщения.")

# Запуск бота
bot.polling(non_stop=True)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 75
#      72         bot.reply_to(message, "Извините, произошла ошибка при обработке вашего сообщения.")
#      74 # Запуск бота
# ---> 75 bot.polling(non_stop=True)
#
# File ~/anaconda3/lib/python3.10/site-packages/telebot/__init__.py:1040, in TeleBot.polling(self, non_stop, skip_pending, interval, timeout, long_polling_timeout, logger_level, allowed_updates, none_stop, restart_on_change, path_to_watch)
#    1037 if restart_on_change:
#    1038     self._setup_change_detector(path_to_watch)
# -> 1040 logger.info('Starting your bot with username: [@%s]', self.user.username)
#    1042 if self.threaded:
#    1043     self.__threaded_polling(non_stop=non_stop, interval=interval, timeout=timeout, long_polling_timeout=long_polling_timeout,
#    1044                             logger_level=logger_level, allowed_updates=allowed_updates)
#
# File ~/anaconda3/lib/python3.10/site-packages/telebot/__init__.py:273, in TeleBot.user(self)
#     265 """
#     266 The User object representing this bot.
#     267 Equivalent to bot.get_me() but the result is cached so only one API call is needed.
#    (...)
#     270 :rtype: :class:`telebot.types.User`
#     271 """
#     272 if not hasattr(self, "_user"):
# --> 273     self._user = self.get_me()
#     274 return self._user
#
# File ~/anaconda3/lib/python3.10/site-packages/telebot/__init__.py:1236, in TeleBot.get_me(self)
#    1229 def get_me(self) -> types.User:
#    1230     """
#    1231     A simple method for testing your bot's authentication token. Requires no parameters.
#    1232     Returns basic information about the bot in form of a User object.
#    1233
#    1234     Telegram documentation: https://core.telegram.org/bots/api#getme
#    1235     """
# -> 1236     result = apihelper.get_me(self.token)
#    1237     return types.User.de_json(result)
#
# File ~/anaconda3/lib/python3.10/site-packages/telebot/apihelper.py:196, in get_me(token)
#     194 def get_me(token):
#     195     method_url = r'getMe'
# --> 196     return _make_request(token, method_url)
#
# File ~/anaconda3/lib/python3.10/site-packages/telebot/apihelper.py:80, in _make_request(token, method_name, method, params, files)
#      70 """
#      71 Makes a request to the Telegram API.
#      72 :param token: The bot's API token. (Created with @BotFather)
#    (...)
#      77 :return: The result parsed to a JSON dictionary.
#      78 """
#      79 if not token:
# ---> 80     raise Exception('Bot token is not defined')
#      81 if API_URL:
#      82     # noinspection PyUnresolvedReferences
#      83     request_url = API_URL.format(token, method_name)
#
# Exception: Bot token is not defined
